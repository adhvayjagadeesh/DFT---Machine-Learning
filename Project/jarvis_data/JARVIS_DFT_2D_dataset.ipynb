# %%
import pandas as pd
import os, json

# %%
f = open('/content/jdft_2d-6-6-2019.json', 'r')

data2d=json.load(f)

f.close()

# %%
df=pd.DataFrame(data2d)

print (df)
# Out:
#                         magmom   fin_en  op_gap  \
# 0  {'magmom_out': -0.0003851, 'magmom_osz': -0.0004}  -2.367401    na
# 1       {'magmom_out': 7.9e-06, 'magmom_osz': 0.0} -15.409464  0.0801
# 2      {'magmom_out': 1.89e-05, 'magmom_osz': 0.0} -13.221733  0.2159
# 3      {'magmom_out': -3.2e-06, 'magmom_osz': 0.0}  -8.012764  1.3617
# 4      {'magmom_out': 3.02e-05, 'magmom_osz': 0.0} -14.768825  0.1358
# ..                         ...    ...   ...
# 749    {'magmom_out': 4.2e-06, 'magmom_osz': -0.0} -18.854158  0.1178
# 750     {'magmom_out': -7.3e-06, 'magmom_osz': -0.0} -35.943619   1.301
# 751     {'magmom_out': -4.8e-06, 'magmom_osz': -0.0}  12.138384  1.8036
# 752  {'magmom_out': 0.9391109, 'magmom_osz': 0.9391} -13.562224  1.4097
# 753       {'magmom_out': 1e-07, 'magmom_osz': 0.0} -69.724323  0.0367
#
#                        final_str     mpid  \
# 0  {'lattice': {'a': 4.111785578032976, 'c': 26.4...   mp-10009
# ...
